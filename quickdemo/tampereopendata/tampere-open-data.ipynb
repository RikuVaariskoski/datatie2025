# %%
import pandas as pd


# Read pedestrian and bicycle traffic data from Tampere open data API

import requests

# Fetch data from API
response = requests.get(url)
data = response.json()

# Save raw response to file for inspection
with open('tampere_traffic_raw.json', 'w') as f:
    f.write(str(data))


df = pd.DataFrame(data['result']['records'])


df
# Out:
#    _id                                                FID  seq_id  \
# 0    1  liikennemaarat_jalankulku_pyoraily_point_TM35.128     128
# 1    2  liikennemaarat_jalankulku_pyoraily_point_TM35.129     129
# 2    3  liikennemaarat_jalankulku_pyoraily_point_TM35.130     130
# 3    4  liikennemaarat_jalankulku_pyoraily_point_TM35.131     131
# 4    5   liikennemaarat_jalankulku_pyoraily_point_TM35.10      10
#
#                                                 geom  kunta   id  \
# 0  MULTIPOINT ((321707.0000009592 6823168.99998774))    837  128
# 1  MULTIPOINT ((321562.0002009686 6823161.9999876...    837  129
# 2  MULTIPOINT ((321571.9997509681 6823208.9999876...    837  130
# 3  MULTIPOINT ((320690.99985102797 6823705.999987...    837  131
# 4  MULTIPOINT ((328286.99980060576 6822607.999990...    837  010
#
#                                               paikka           kohde  \
# 0             Nokiantie (Tesoman valtatien itäpuoli)  Poikkileikkaus
# 1           Nokiantie (Tesoman valtatien länsipuoli)  Poikkileikkaus
# 2         Tesoman valtatie (Nokiantien pohjoispuoli)  Poikkileikkaus
# 3       Tesoman valtatie (Tesomankadun pohjoispuoli)  Poikkileikkaus
# 4  Itsenäisyydenkatu Rautatietunneli (ei sisätunn...        Alikulku
#
#           laskenta  jk_1992  ...             pvm_2016           saa_2016  \
# 0  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 1  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 2  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 3  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 4  Iltahuipputunti    365.0  ...  2016-06-29T00:00:00  puolipilvinen +22
#
#   jk_2017 pp_2017             pvm_2017           saa_2017  jk_2018 pp_2018  \
# 0      16      32  2017-06-27T00:00:00       sateinen +17       15      72
# 1       6      18  2017-06-27T00:00:00       sateinen +13        4      46
# 2       2      15  2017-06-27T00:00:00       sateinen +13        5      16
# 3      70      33  2017-06-27T00:00:00       sateinen +13       35      36
# 4      79     154  2017-06-21T00:00:00  puolipilvinen +12       81     102
#
#               pvm_2018           saa_2018
# 0  2018-06-26T00:00:00  puolipilvinen +22
# 1  2018-06-26T00:00:00  puolipilvinen +22
# 2  2018-06-26T00:00:00  puolipilvinen +22
# 3  2018-06-26T00:00:00  puolipilvinen +22
# 4  2018-06-27T00:00:00    aurinkoinen +25
#
# [5 rows x 85 columns]

# %%
df = pd.DataFrame(data['result']['records'])

# %%
df
# Out:
#    _id                                                FID  seq_id  \
# 0    1  liikennemaarat_jalankulku_pyoraily_point_TM35.128     128
# 1    2  liikennemaarat_jalankulku_pyoraily_point_TM35.129     129
# 2    3  liikennemaarat_jalankulku_pyoraily_point_TM35.130     130
# 3    4  liikennemaarat_jalankulku_pyoraily_point_TM35.131     131
# 4    5   liikennemaarat_jalankulku_pyoraily_point_TM35.10      10
#
#                                                 geom  kunta   id  \
# 0  MULTIPOINT ((321707.0000009592 6823168.99998774))    837  128
# 1  MULTIPOINT ((321562.0002009686 6823161.9999876...    837  129
# 2  MULTIPOINT ((321571.9997509681 6823208.9999876...    837  130
# 3  MULTIPOINT ((320690.99985102797 6823705.999987...    837  131
# 4  MULTIPOINT ((328286.99980060576 6822607.999990...    837  010
#
#                                               paikka           kohde  \
# 0             Nokiantie (Tesoman valtatien itäpuoli)  Poikkileikkaus
# 1           Nokiantie (Tesoman valtatien länsipuoli)  Poikkileikkaus
# 2         Tesoman valtatie (Nokiantien pohjoispuoli)  Poikkileikkaus
# 3       Tesoman valtatie (Tesomankadun pohjoispuoli)  Poikkileikkaus
# 4  Itsenäisyydenkatu Rautatietunneli (ei sisätunn...        Alikulku
#
#           laskenta  jk_1992  ...             pvm_2016           saa_2016  \
# 0  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 1  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 2  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 3  Iltahuipputunti      NaN  ...  2016-07-05T00:00:00       pilvinen +17
# 4  Iltahuipputunti    365.0  ...  2016-06-29T00:00:00  puolipilvinen +22
#
#   jk_2017 pp_2017             pvm_2017           saa_2017  jk_2018 pp_2018  \
# 0      16      32  2017-06-27T00:00:00       sateinen +17       15      72
# 1       6      18  2017-06-27T00:00:00       sateinen +13        4      46
# 2       2      15  2017-06-27T00:00:00       sateinen +13        5      16
# 3      70      33  2017-06-27T00:00:00       sateinen +13       35      36
# 4      79     154  2017-06-21T00:00:00  puolipilvinen +12       81     102
#
#               pvm_2018           saa_2018
# 0  2018-06-26T00:00:00  puolipilvinen +22
# 1  2018-06-26T00:00:00  puolipilvinen +22
# 2  2018-06-26T00:00:00  puolipilvinen +22
# 3  2018-06-26T00:00:00  puolipilvinen +22
# 4  2018-06-27T00:00:00    aurinkoinen +25
#
# [5 rows x 85 columns]
